# %%
import pandas as pd
import numpy as np
import logging

# Configuração do logging
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

data = {
    "Aspecto": ["Sol", "Sol", "Nuvens", "Chuva", "Chuva", "Chuva", "Nuvens", "Sol", "Sol", "Chuva", "Sol", "Nuvens", "Nuvens", "Chuva"],
    "Temp": ["Quente", "Quente", "Quente", "Ameno", "Fresco", "Fresco", "Fresco", "Ameno", "Fresco", "Ameno", "Ameno", "Quente", "Quente", "Ameno"],
    "Humidade": ["Elevada", "Elevada", "Elevada", "Elevada", "Normal", "Normal", "Normal", "Normal", "Normal", "Elevada", "Normal", "Elevada", "Normal", "Elevada"],
    "Vento": ["Fraco", "Forte", "Fraco", "Fraco", "Fraco", "Forte", "Fraco", "Forte", "Fraco", "Fraco", "Forte", "Fraco", "Forte", "Forte"],
    "Tenis": ["Não", "Não", "Sim", "Sim", "Sim", "Não", "Sim", "Não", "Sim", "Sim", "Sim", "Sim", "Sim", "Não"]
}
df = pd.DataFrame(data)
X = df.drop(columns=['Tenis'])  
y = df['Tenis']

def entropia(col):
    counts = np.unique(col, return_counts=True)
    N = float(col.shape[0])
    ent = 0.0
    for ix in counts[1]:
        p = ix / N
        ent += -1.0 * p * np.log2(p)
    logging.debug(f"Entropia calculada: {ent} para coluna: {col.name if hasattr(col, 'name') else col}")
    return ent

def information_gain(df, attr, target):
    total = entropia(df[target])
    valores = np.unique(df[attr])
    acc = 0
    logging.debug(f"Calculando information gain para atributo '{attr}'")
    for v in valores:
        subset = df[df[attr] == v][target]
        x = len(subset) / len(df)
        ent_sub = entropia(subset)
        acc += x * ent_sub
        logging.debug(f"Valor {v}: proporção={x:.3f}, entropia={ent_sub:.3f}, acc parcial={acc:.3f}")
    ig = total - acc
    logging.debug(f"Information Gain para '{attr}': {ig:.3f}")
    return ig

class DecisionTreeCategorical:
    def __init__(self, depth=0, max_depth=3):
        self.children = {}
        self.attr = None
        self.max_depth = max_depth
        self.depth = depth
        self.target = None

    def train(self, df, features, target):
        logging.debug(f"{'  '*self.depth}Treinando nó (profundidade={self.depth}) com {len(df)} exemplos. Features: {features}")
        # Se todos são iguais, ou acabou feature, vira folha
        if len(np.unique(df[target])) == 1 or len(features) == 0 or self.depth >= self.max_depth:
            self.target = df[target].mode()[0]
            logging.debug(f"{'  '*self.depth}Nó folha criado com target={self.target}")
            return

        # Escolhe melhor atributo
        gains = [information_gain(df, attr, target) for attr in features]
        best_attr = features[np.argmax(gains)]
        self.attr = best_attr
        self.children = {}
        logging.debug(f"{'  '*self.depth}Melhor atributo para split: {best_attr}")

        for v in np.unique(df[best_attr]):
            subset = df[df[best_attr] == v]
            logging.debug(f"{'  '*self.depth}Criando filho para valor '{v}' ({len(subset)} exemplos)")
            if subset.empty:
                self.children[v] = None
            else:
                child = DecisionTreeCategorical(depth=self.depth+1, max_depth=self.max_depth)
                child.train(subset, [f for f in features if f != best_attr], target)
                self.children[v] = child

    def predict(self, row):
        if self.attr is None or self.children == {}:
            logging.debug(f"Predição em nó folha: retorna {self.target}")
            return self.target
        val = row[self.attr]
        logging.debug(f"Testando atributo '{self.attr}' com valor '{val}'")
        if val in self.children and self.children[val] is not None:
            return self.children[val].predict(row)
        else:
            logging.debug(f"Valor '{val}' não encontrado, retorna modo do nó: {self.target}")
            return self.target  # fallback para modo do nó

# Treinando a árvore
features = ["Aspecto", "Temp", "Humidade", "Vento"]
target = "Tenis"
tree = DecisionTreeCategorical(max_depth=3)
tree.train(df, features, target)

# Testando as previsões
for i in range(len(df)):
    test_row = df.iloc[i]
    previsto = tree.predict(test_row)
    real = test_row[target]
    logging.info(f"Exemplo {i+1}: Previsto={previsto}, Real={real}")
# Out:
# 2025-05-21 16:57:22,535 - DEBUG - Treinando nó (profundidade=0) com 14 exemplos. Features: ['Aspecto', 'Temp', 'Humidade', 'Vento']
# 2025-05-21 16:57:22,537 - DEBUG - Entropia calculada: 0.9402859586706311 para coluna: Tenis
# 2025-05-21 16:57:22,538 - DEBUG - Calculando information gain para atributo 'Aspecto'
# 2025-05-21 16:57:22,539 - DEBUG - Entropia calculada: 0.9709505944546686 para coluna: Tenis
# 2025-05-21 16:57:22,540 - DEBUG - Valor Chuva: proporção=0.357, entropia=0.971, acc parcial=0.347
# 2025-05-21 16:57:22,542 - DEBUG - Entropia calculada: 0.0 para coluna: Tenis
# 2025-05-21 16:57:22,543 - DEBUG - Valor Nuvens: proporção=0.286, entropia=0.000, acc parcial=0.347
# 2025-05-21 16:57:22,545 - DEBUG - Entropia calculada: 0.9709505944546686 para coluna: Tenis
# 2025-05-21 16:57:22,545 - DEBUG - Valor Sol: proporção=0.357, entropia=0.971, acc parcial=0.694
# 2025-05-21 16:57:22,546 - DEBUG - Information Gain para 'Aspecto': 0.247
# 2025-05-21 16:57:22,547 - DEBUG - Entropia calculada: 0.9402859586706311 para coluna: Tenis
# 2025-05-21 16:57:22,548 - DEBUG - Calculando information gain para atributo 'Temp'
# 2025-05-21 16:57:22,549 - DEBUG - Entropia calculada: 0.9709505944546686 para coluna: Tenis
# 2025-05-21 16:57:22,550 - DEBUG - Valor Ameno: proporção=0.357, entropia=0.971, acc parcial=0.347
# 2025-05-21 16:57:22,552 - DEBUG - Entropia calculada: 0.8112781244591328 para coluna: Tenis
# 2025-05-21 16:57:22,554 - DEBUG - Valor Fresco: proporção=0.286, entropia=0.811, acc parcial=0.579
# 2025-05-21 16:57:22,555 - DEBUG - Entropia calculada: 0.9709505944546686 para coluna: Tenis
# 2025-05-21 16:57:22,556 - DEBUG - Valor Quente: proporção=0.357, entropia=0.971, acc parcial=0.925
# 2025-05-21 16:57:22,557 - DEBUG - Information Gain para 'Temp': 0.015
# 2025-05-21 16:57:22,558 - DEBUG - Entropia calculada: 0.9402859586706311 para coluna: Tenis
# 2025-05-21 16:57:22,559 - DEBUG - Calculando information gain para atributo 'Humidade'
# 2025-05-21 16:57:22,561 - DEBUG - Entropia calculada: 0.9852281360342515 para coluna: Tenis
# 2025-05-21 16:57:22,562 - DEBUG - Valor Elevada: proporção=0.500, entropia=0.985, acc parcial=0.493
# 2025-05-21 16:57:22,564 - DEBUG - Entropia calculada: 0.863120568566631 para coluna: Tenis
# 2025-05-21 16:57:22,565 - DEBUG - Valor Normal: proporção=0.500, entropia=0.863, acc parcial=0.924
# 2025-05-21 16:57:22,566 - DEBUG - Information Gain para 'Humidade': 0.016
# 2025-05-21 16:57:22,567 - DEBUG - Entropia calculada: 0.9402859586706311 para coluna: Tenis
# 2025-05-21 16:57:22,569 - DEBUG - Calculando information gain para atributo 'Vento'
# 2025-05-21 16:57:22,570 - DEBUG - Entropia calculada: 0.9182958340544896 para coluna: Tenis
# 2025-05-21 16:57:22,571 - DEBUG - Valor Forte: proporção=0.429, entropia=0.918, acc parcial=0.394
# 2025-05-21 16:57:22,573 - DEBUG - Entropia calculada: 0.5435644431995964 para coluna: Tenis
# 2025-05-21 16:57:22,574 - DEBUG - Valor Fraco: proporção=0.571, entropia=0.544, acc parcial=0.704
# 2025-05-21 16:57:22,575 - DEBUG - Information Gain para 'Vento': 0.236
# 2025-05-21 16:57:22,576 - DEBUG - Melhor atributo para split: Aspecto
# 2025-05-21 16:57:22,578 - DEBUG - Criando filho para valor 'Chuva' (5 exemplos)
# 2025-05-21 16:57:22,579 - DEBUG -   Treinando nó (profundidade=1) com 5 exemplos. Features: ['Temp', 'Humidade', 'Vento']
# 2025-05-21 16:57:22,580 - DEBUG - Entropia calculada: 0.9709505944546686 para coluna: Tenis
# 2025-05-21 16:57:22,582 - DEBUG - Calculando information gain para atributo 'Temp'
# 2025-05-21 16:57:22,584 - DEBUG - Entropia calculada: 0.9182958340544896 para coluna: Tenis
# 2025-05-21 16:57:22,585 - DEBUG - Valor Ameno: proporção=0.600, entropia=0.918, acc parcial=0.551
# 2025-05-21 16:57:22,587 - DEBUG - Entropia calculada: 1.0 para coluna: Tenis
# 2025-05-21 16:57:22,588 - DEBUG - Valor Fresco: proporção=0.400, entropia=1.000, acc parcial=0.951
# 2025-05-21 16:57:22,589 - DEBUG - Information Gain para 'Temp': 0.020
# 2025-05-21 16:57:22,590 - DEBUG - Entropia calculada: 0.9709505944546686 para coluna: Tenis
# 2025-05-21 16:57:22,591 - DEBUG - Calculando information gain para atributo 'Humidade'
# 2025-05-21 16:57:22,593 - DEBUG - Entropia calculada: 0.9182958340544896 para coluna: Tenis
# 2025-05-21 16:57:22,594 - DEBUG - Valor Elevada: proporção=0.600, entropia=0.918, acc parcial=0.551
# 2025-05-21 16:57:22,596 - DEBUG - Entropia calculada: 1.0 para coluna: Tenis
# 2025-05-21 16:57:22,597 - DEBUG - Valor Normal: proporção=0.400, entropia=1.000, acc parcial=0.951
# 2025-05-21 16:57:22,597 - DEBUG - Information Gain para 'Humidade': 0.020
# 2025-05-21 16:57:22,599 - DEBUG - Entropia calculada: 0.9709505944546686 para coluna: Tenis
# 2025-05-21 16:57:22,600 - DEBUG - Calculando information gain para atributo 'Vento'
# 2025-05-21 16:57:22,601 - DEBUG - Entropia calculada: 0.0 para coluna: Tenis
# 2025-05-21 16:57:22,602 - DEBUG - Valor Forte: proporção=0.400, entropia=0.000, acc parcial=0.000
# 2025-05-21 16:57:22,604 - DEBUG - Entropia calculada: 0.0 para coluna: Tenis
# 2025-05-21 16:57:22,605 - DEBUG - Valor Fraco: proporção=0.600, entropia=0.000, acc parcial=0.000
# 2025-05-21 16:57:22,606 - DEBUG - Information Gain para 'Vento': 0.971
# 2025-05-21 16:57:22,607 - DEBUG -   Melhor atributo para split: Vento
# 2025-05-21 16:57:22,608 - DEBUG -   Criando filho para valor 'Forte' (2 exemplos)
# 2025-05-21 16:57:22,609 - DEBUG -     Treinando nó (profundidade=2) com 2 exemplos. Features: ['Temp', 'Humidade']
# 2025-05-21 16:57:22,610 - DEBUG -     Nó folha criado com target=Não
# 2025-05-21 16:57:22,612 - DEBUG -   Criando filho para valor 'Fraco' (3 exemplos)
# 2025-05-21 16:57:22,613 - DEBUG -     Treinando nó (profundidade=2) com 3 exemplos. Features: ['Temp', 'Humidade']
# 2025-05-21 16:57:22,614 - DEBUG -     Nó folha criado com target=Sim
# 2025-05-21 16:57:22,616 - DEBUG - Criando filho para valor 'Nuvens' (4 exemplos)
# 2025-05-21 16:57:22,617 - DEBUG -   Treinando nó (profundidade=1) com 4 exemplos. Features: ['Temp', 'Humidade', 'Vento']
# 2025-05-21 16:57:22,618 - DEBUG -   Nó folha criado com target=Sim
# 2025-05-21 16:57:22,620 - DEBUG - Criando filho para valor 'Sol' (5 exemplos)
# 2025-05-21 16:57:22,621 - DEBUG -   Treinando nó (profundidade=1) com 5 exemplos. Features: ['Temp', 'Humidade', 'Vento']
# 2025-05-21 16:57:22,622 - DEBUG - Entropia calculada: 0.9709505944546686 para coluna: Tenis
# 2025-05-21 16:57:22,623 - DEBUG - Calculando information gain para atributo 'Temp'
# 2025-05-21 16:57:22,625 - DEBUG - Entropia calculada: 1.0 para coluna: Tenis
# 2025-05-21 16:57:22,626 - DEBUG - Valor Ameno: proporção=0.400, entropia=1.000, acc parcial=0.400
# 2025-05-21 16:57:22,627 - DEBUG - Entropia calculada: 0.0 para coluna: Tenis
# 2025-05-21 16:57:22,628 - DEBUG - Valor Fresco: proporção=0.200, entropia=0.000, acc parcial=0.400
# 2025-05-21 16:57:22,630 - DEBUG - Entropia calculada: 0.0 para coluna: Tenis
# 2025-05-21 16:57:22,631 - DEBUG - Valor Quente: proporção=0.400, entropia=0.000, acc parcial=0.400
# 2025-05-21 16:57:22,632 - DEBUG - Information Gain para 'Temp': 0.571
# 2025-05-21 16:57:22,633 - DEBUG - Entropia calculada: 0.9709505944546686 para coluna: Tenis
# 2025-05-21 16:57:22,634 - DEBUG - Calculando information gain para atributo 'Humidade'
# 2025-05-21 16:57:22,636 - DEBUG - Entropia calculada: 0.0 para coluna: Tenis
# 2025-05-21 16:57:22,637 - DEBUG - Valor Elevada: proporção=0.400, entropia=0.000, acc parcial=0.000
# 2025-05-21 16:57:22,639 - DEBUG - Entropia calculada: 0.9182958340544896 para coluna: Tenis
# 2025-05-21 16:57:22,640 - DEBUG - Valor Normal: proporção=0.600, entropia=0.918, acc parcial=0.551
# 2025-05-21 16:57:22,641 - DEBUG - Information Gain para 'Humidade': 0.420
# 2025-05-21 16:57:22,642 - DEBUG - Entropia calculada: 0.9709505944546686 para coluna: Tenis
# 2025-05-21 16:57:22,643 - DEBUG - Calculando information gain para atributo 'Vento'
# 2025-05-21 16:57:22,645 - DEBUG - Entropia calculada: 0.9182958340544896 para coluna: Tenis
# 2025-05-21 16:57:22,648 - DEBUG - Valor Forte: proporção=0.600, entropia=0.918, acc parcial=0.551
# 2025-05-21 16:57:22,650 - DEBUG - Entropia calculada: 1.0 para coluna: Tenis
# 2025-05-21 16:57:22,651 - DEBUG - Valor Fraco: proporção=0.400, entropia=1.000, acc parcial=0.951
# 2025-05-21 16:57:22,652 - DEBUG - Information Gain para 'Vento': 0.020
# 2025-05-21 16:57:22,653 - DEBUG -   Melhor atributo para split: Temp
# 2025-05-21 16:57:22,656 - DEBUG -   Criando filho para valor 'Ameno' (2 exemplos)
# 2025-05-21 16:57:22,657 - DEBUG -     Treinando nó (profundidade=2) com 2 exemplos. Features: ['Humidade', 'Vento']
# 2025-05-21 16:57:22,658 - DEBUG - Entropia calculada: 1.0 para coluna: Tenis
# 2025-05-21 16:57:22,659 - DEBUG - Calculando information gain para atributo 'Humidade'
# 2025-05-21 16:57:22,660 - DEBUG - Entropia calculada: 1.0 para coluna: Tenis
# 2025-05-21 16:57:22,661 - DEBUG - Valor Normal: proporção=1.000, entropia=1.000, acc parcial=1.000
# 2025-05-21 16:57:22,662 - DEBUG - Information Gain para 'Humidade': 0.000
# 2025-05-21 16:57:22,663 - DEBUG - Entropia calculada: 1.0 para coluna: Tenis
# 2025-05-21 16:57:22,665 - DEBUG - Calculando information gain para atributo 'Vento'
# 2025-05-21 16:57:22,666 - DEBUG - Entropia calculada: 1.0 para coluna: Tenis
# 2025-05-21 16:57:22,667 - DEBUG - Valor Forte: proporção=1.000, entropia=1.000, acc parcial=1.000
# 2025-05-21 16:57:22,668 - DEBUG - Information Gain para 'Vento': 0.000
# 2025-05-21 16:57:22,669 - DEBUG -     Melhor atributo para split: Humidade
# 2025-05-21 16:57:22,670 - DEBUG -     Criando filho para valor 'Normal' (2 exemplos)
# 2025-05-21 16:57:22,671 - DEBUG -       Treinando nó (profundidade=3) com 2 exemplos. Features: ['Vento']
# 2025-05-21 16:57:22,673 - DEBUG -       Nó folha criado com target=Não
# 2025-05-21 16:57:22,674 - DEBUG -   Criando filho para valor 'Fresco' (1 exemplos)
# 2025-05-21 16:57:22,675 - DEBUG -     Treinando nó (profundidade=2) com 1 exemplos. Features: ['Humidade', 'Vento']
# 2025-05-21 16:57:22,677 - DEBUG -     Nó folha criado com target=Sim
# 2025-05-21 16:57:22,679 - DEBUG -   Criando filho para valor 'Quente' (2 exemplos)
# 2025-05-21 16:57:22,679 - DEBUG -     Treinando nó (profundidade=2) com 2 exemplos. Features: ['Humidade', 'Vento']
# 2025-05-21 16:57:22,681 - DEBUG -     Nó folha criado com target=Não
# 2025-05-21 16:57:22,682 - DEBUG - Testando atributo 'Aspecto' com valor 'Sol'
# 2025-05-21 16:57:22,683 - DEBUG - Testando atributo 'Temp' com valor 'Quente'
# 2025-05-21 16:57:22,684 - DEBUG - Predição em nó folha: retorna Não
# 2025-05-21 16:57:22,686 - INFO - Exemplo 1: Previsto=Não, Real=Não
# 2025-05-21 16:57:22,687 - DEBUG - Testando atributo 'Aspecto' com valor 'Sol'
# 2025-05-21 16:57:22,688 - DEBUG - Testando atributo 'Temp' com valor 'Quente'
# 2025-05-21 16:57:22,689 - DEBUG - Predição em nó folha: retorna Não
# 2025-05-21 16:57:22,689 - INFO - Exemplo 2: Previsto=Não, Real=Não
# 2025-05-21 16:57:22,690 - DEBUG - Testando atributo 'Aspecto' com valor 'Nuvens'
# 2025-05-21 16:57:22,691 - DEBUG - Predição em nó folha: retorna Sim
# 2025-05-21 16:57:22,692 - INFO - Exemplo 3: Previsto=Sim, Real=Sim
# 2025-05-21 16:57:22,693 - DEBUG - Testando atributo 'Aspecto' com valor 'Chuva'
# 2025-05-21 16:57:22,694 - DEBUG - Testando atributo 'Vento' com valor 'Fraco'
# 2025-05-21 16:57:22,695 - DEBUG - Predição em nó folha: retorna Sim
# 2025-05-21 16:57:22,695 - INFO - Exemplo 4: Previsto=Sim, Real=Sim
# 2025-05-21 16:57:22,697 - DEBUG - Testando atributo 'Aspecto' com valor 'Chuva'
# 2025-05-21 16:57:22,698 - DEBUG - Testando atributo 'Vento' com valor 'Fraco'
# 2025-05-21 16:57:22,699 - DEBUG - Predição em nó folha: retorna Sim
# 2025-05-21 16:57:22,700 - INFO - Exemplo 5: Previsto=Sim, Real=Sim
# 2025-05-21 16:57:22,701 - DEBUG - Testando atributo 'Aspecto' com valor 'Chuva'
# 2025-05-21 16:57:22,701 - DEBUG - Testando atributo 'Vento' com valor 'Forte'
# 2025-05-21 16:57:22,702 - DEBUG - Predição em nó folha: retorna Não
# 2025-05-21 16:57:22,703 - INFO - Exemplo 6: Previsto=Não, Real=Não
# 2025-05-21 16:57:22,704 - DEBUG - Testando atributo 'Aspecto' com valor 'Nuvens'
# 2025-05-21 16:57:22,705 - DEBUG - Predição em nó folha: retorna Sim
# 2025-05-21 16:57:22,706 - INFO - Exemplo 7: Previsto=Sim, Real=Sim
# 2025-05-21 16:57:22,707 - DEBUG - Testando atributo 'Aspecto' com valor 'Sol'
# 2025-05-21 16:57:22,708 - DEBUG - Testando atributo 'Temp' com valor 'Ameno'
# 2025-05-21 16:57:22,708 - DEBUG - Testando atributo 'Humidade' com valor 'Normal'
# 2025-05-21 16:57:22,709 - DEBUG - Predição em nó folha: retorna Não
# 2025-05-21 16:57:22,710 - INFO - Exemplo 8: Previsto=Não, Real=Não
# 2025-05-21 16:57:22,711 - DEBUG - Testando atributo 'Aspecto' com valor 'Sol'
# 2025-05-21 16:57:22,711 - DEBUG - Testando atributo 'Temp' com valor 'Fresco'
# 2025-05-21 16:57:22,712 - DEBUG - Predição em nó folha: retorna Sim
# 2025-05-21 16:57:22,713 - INFO - Exemplo 9: Previsto=Sim, Real=Sim
# 2025-05-21 16:57:22,714 - DEBUG - Testando atributo 'Aspecto' com valor 'Chuva'
# 2025-05-21 16:57:22,715 - DEBUG - Testando atributo 'Vento' com valor 'Fraco'
# 2025-05-21 16:57:22,715 - DEBUG - Predição em nó folha: retorna Sim
# 2025-05-21 16:57:22,716 - INFO - Exemplo 10: Previsto=Sim, Real=Sim
# 2025-05-21 16:57:22,717 - DEBUG - Testando atributo 'Aspecto' com valor 'Sol'
# 2025-05-21 16:57:22,718 - DEBUG - Testando atributo 'Temp' com valor 'Ameno'
# 2025-05-21 16:57:22,718 - DEBUG - Testando atributo 'Humidade' com valor 'Normal'
# 2025-05-21 16:57:22,719 - DEBUG - Predição em nó folha: retorna Não
# 2025-05-21 16:57:22,720 - INFO - Exemplo 11: Previsto=Não, Real=Sim
# 2025-05-21 16:57:22,721 - DEBUG - Testando atributo 'Aspecto' com valor 'Nuvens'
# 2025-05-21 16:57:22,722 - DEBUG - Predição em nó folha: retorna Sim
# 2025-05-21 16:57:22,722 - INFO - Exemplo 12: Previsto=Sim, Real=Sim
# 2025-05-21 16:57:22,723 - DEBUG - Testando atributo 'Aspecto' com valor 'Nuvens'
# 2025-05-21 16:57:22,724 - DEBUG - Predição em nó folha: retorna Sim
# 2025-05-21 16:57:22,725 - INFO - Exemplo 13: Previsto=Sim, Real=Sim
# 2025-05-21 16:57:22,725 - DEBUG - Testando atributo 'Aspecto' com valor 'Chuva'
# 2025-05-21 16:57:22,726 - DEBUG - Testando atributo 'Vento' com valor 'Forte'
# 2025-05-21 16:57:22,727 - DEBUG - Predição em nó folha: retorna Não
# 2025-05-21 16:57:22,728 - INFO - Exemplo 14: Previsto=Não, Real=Não
